# %% [markdown]
# # Manual Test

# %%
import rouge_score
from typing_extensions import TypedDict
from typing import List
from agents.DOCSQNA import graph
class Message(TypedDict):
    role:str
    content:str

class QnaState(TypedDict):
    messages: List[Message]

def get_answer(question:str):
    state = QnaState(messages=[Message(role='user',content=question)])
    answer = graph.invoke(state)['answer']
    return answer

# %%
from langchain_community.document_loaders import PyMuPDFLoader
import re
def split_by_numbered_items(text, keep_separators=True):
    pattern = r'(\d+\.)'
    
    if keep_separators:
        chunks = re.split(pattern, text)
        result = []
        for i in range(1, len(chunks), 2):
            if i + 1 < len(chunks):
                chunk = chunks[i] + chunks[i + 1]
                result.append(chunk.strip())
            else:
                result.append(chunks[i].strip())
        
        if chunks[0].strip():
            result.insert(0, chunks[0].strip())
            
    else:
        chunks = re.split(pattern, text)
        result = []
        for chunk in chunks:
            stripped = chunk.strip()
            if stripped and not re.match(r'\d+\.$', stripped):
                if "\n \n" in stripped:
                    stripped = stripped.split("\n \n")[0].strip()
                if stripped:
                    result.append(stripped)
    
    return result

loader = PyMuPDFLoader("docs/FAQ Dexa Medica.pdf")
docs = loader.load()
chunk_text = split_by_numbered_items(''.join([doc.page_content for doc in docs]), keep_separators=False)
qna_result = [
    {
        "question": chunk.split('?', 1)[0].strip() + '?',
        "answer": chunk.split('?', 1)[1].strip() if '?' in chunk else ''
    }
    for chunk in chunk_text if '?' in chunk
]

# %%
import pandas as pd

df = pd.DataFrame.from_records(qna_result)

# %%
df
# Out:
#                                              question  \
# 0                                Apa itu Dexa Medica?
# 1                          Apa visi dari Dexa Medica?
# 2                    Apa saja nilai inti Dexa Medica?
# 3                               Apa arti nama 'Dexa'?
# 4               Apa saja kompetensi inti Dexa Medica?
# 5                                       Apa itu OMAI?
# 6                   Apa yang dimaksud dengan OGBdexa?
# 7   Berapa jumlah obat yang telah diluncurkan Dexa...
# 8         Apakah Dexa Medica memproduksi obat herbal?
# 9                                       Apa itu DLBS?
# 10                 Di mana lokasi pabrik Dexa Medica?
# 11             Apa itu Dexa Development Center (DDC)?
# 12      Apakah Dexa Medica memiliki sertifikasi CPOB?
# 13  Berapa kapasitas produksi OGB Dexa Medica per ...
# 14       Bagaimana cara melamar kerja di Dexa Medica?
# 15  Apa yang dicari Dexa Medica dalam calon karyawan?
# 16  Bagaimana cara menghubungi Dexa Medica untuk i...
# 17          Apakah Dexa Medica aktif di media sosial?
# 18  Apakah Dexa Medica hanya beroperasi di Indonesia?
# 19  Apa kontribusi Dexa Medica terhadap sistem kes...
# 20  Apa yang membedakan Dexa Medica dari perusahaa...
# 21             Apakah Dexa Medica memproduksi vaksin?
# 22  Apakah Dexa Medica menerima kunjungan industri...
# 23  Bisakah masyarakat umum membeli produk Dexa Me...
# 24  Apakah Dexa Medica menyediakan layanan konsult...
# 25           Apakah Dexa Medica memiliki program CSR?
# 26  Apakah Dexa Medica terdaftar di Bursa Efek Ind...
# 27  Bagaimana Dexa Medica memastikan kualitas baha...
# 28  Apakah Dexa Medica memiliki produk untuk penya...
# 29  Apa itu sistem NDDS yang dikembangkan Dexa Med...
# 30  Apakah Dexa Medica menjual produk di luar negeri?
# 31            Siapa saja mitra strategis Dexa Medica?
# 32               Apakah Dexa Medica ramah lingkungan?
# 33  Bagaimana Dexa Medica menjaga keamanan data pa...
# 34  Apakah Dexa Medica terlibat dalam riset kanker...
# 35  Bagaimana cara mendapatkan brosur produk Dexa ...
# 36  Apakah Dexa Medica memiliki program magang unt...
# 37     Apakah Dexa Medica menjual suplemen kesehatan?
# 38  Apa jenis pelatihan yang diberikan kepada kary...
# 39  Apakah Dexa Medica pernah menerima penghargaan...
# 40                 Apakah Dexa Medica mendukung UMKM?
# 41  Bagaimana prosedur kerja sama bisnis dengan De...
# 42    Apakah Dexa Medica memiliki call center 24 jam?
# 43  Apa jenis produk yang diproduksi di pabrik Kar...
# 44  Apakah Dexa Medica menggunakan teknologi AI da...
# 45  Bagaimana Dexa Medica menangani keluhan konsumen?
# 46    Apakah produk Dexa Medica aman untuk ibu hamil?
# 47       Apakah Dexa Medica melakukan edukasi publik?
# 48  Apakah Dexa Medica memiliki produk OTC (over-t...
# 49                             Apa motto Dexa Medica?
#
#                                                answer
# 0   Dexa Medica adalah salah satu perusahaan farma...
# 1   Visi Dexa Medica adalah menjadi perusahaan ter...
# 2   Nilai inti Dexa Medica adalah: \no Strive for ...
# 3   Nama "Dexa" berasal dari bahasa Yunani "δέκα" ...
# 4   Kompetensi inti Dexa Medica meliputi: \no Peng...
# 5   OMAI (Obat Modern Asli Indonesia) adalah obat ...
# 6   OGBdexa adalah lini produk Obat Generik Berlog...
# 7   Lebih dari 50 obat baru telah diluncurkan dala...
# 8   Ya, melalui divisi DLBS (Dexa Laboratories of ...
# 9   DLBS adalah divisi riset Dexa Medica yang foku...
# 10  Dexa Medica memiliki pabrik di: \n• Palembang ...
# 11  DDC adalah pusat penelitian di Cikarang yang m...
# 12  Ya, Dexa Medica adalah satu dari lima perusaha...
# 13  Dexa Medica memproduksi lebih dari 1 miliar un...
# 14  Anda bisa melamar melalui situs dexagroupcaree...
# 15  Profesionalisme, dedikasi, integritas, kemampu...
# 16  Anda bisa menghubungi melalui email: info@dexa...
# 17  Ya. Dexa Medica aktif di Instagram, Facebook, ...
# 18  Tidak. Meskipun berbasis di Indonesia, Dexa Me...
# 19  Dexa Medica berkontribusi melalui penyediaan o...
# 20  Dexa Medica menggabungkan penelitian biomoleku...
# 21  Saat ini Dexa Medica fokus pada obat generik, ...
# 22  Ya, Dexa Medica menerima kunjungan akademik de...
# 23  Tidak. Dexa Medica mendistribusikan produknya ...
# 24  Dexa Medica tidak menyediakan layanan medis la...
# 25  Ya, program tanggung jawab sosial Dexa Medica ...
# 26  Tidak, Dexa Medica adalah perusahaan swasta da...
# 27  Bahan baku dipilih melalui proses pengujian ke...
# 28  Ya, Dexa Medica memproduksi berbagai obat untu...
# 29  NDDS (New Drug Delivery System) adalah teknolo...
# 30  Ya, Dexa Medica mengekspor beberapa produknya ...
# 31  Dexa Medica bermitra dengan berbagai institusi...
# 32  Dexa Medica menerapkan kebijakan produksi hija...
# 33  Dexa Medica menerapkan sistem keamanan informa...
# 34  Dexa Medica terus mengeksplorasi pengembangan ...
# 35  Brosur produk dapat diperoleh melalui distribu...
# 36  Ya, Dexa Medica membuka program internship unt...
# 37  Ya, melalui anak perusahaan dan divisi khusus,...
# 38  Karyawan baru mengikuti pelatihan orientasi, G...
# 39  Ya, Dexa Medica telah menerima berbagai pengha...
# 40  Dexa Medica bekerja sama dengan petani lokal d...
# 41  Calon mitra dapat mengirim proposal resmi ke \...
# 42  Saat ini Dexa Medica tidak memiliki call cente...
# 43  Pabrik Beta Pharmacon di Karawang memproduksi ...
# 44  Dexa Medica mulai mengintegrasikan kecerdasan ...
# 45  Keluhan dapat diajukan melalui formulir kontak...
# 46  Beberapa produk Dexa aman untuk ibu hamil, nam...
# 47  Ya, Dexa Medica rutin mengadakan webinar, kamp...
# 48  Ya, Dexa Medica memproduksi beberapa produk ya...
# 49  Motto Dexa Medica adalah: “Pemanfaatan keahlia...

# %%
df.to_csv('qna.csv')

# %%
df['llm_answer'] = df['question'].apply(get_answer)

# %%
from rouge_score import rouge_scorer

scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)

def compute_rouge_scores(row):
    reference = row['answer']
    hypothesis = row['llm_answer']
    # Compute ROUGE-L F1 score
    scores = scorer.score(reference, hypothesis)
    return scores['rougeL'].fmeasure

df['rouge_l_f1'] = df.apply(compute_rouge_scores, axis=1)

# %%
for col in df.columns:
    print(f"{col}: {df.iloc[15][col]}")
# Out:
# question: Apa yang dicari Dexa Medica dalam calon karyawan?
# answer: Profesionalisme, dedikasi, integritas, kemampuan berinovasi, dan semangat kolaborasi.
# llm_answer: Dexa Medica mencari profesionalisme, dedikasi, integritas, kemampuan berinovasi, dan semangat kolaborasi dalam calon karyawan.
# rouge_l_f1: 0.7272727272727273

# %%
df.rouge_l_f1.mean()
# Out:
# 0.943746023455189

# %%
for col, val in df.iloc[15].items():
    print(f"{col}: {val}")
# Out:
# question: Apa yang dicari Dexa Medica dalam calon karyawan?
# answer: Profesionalisme, dedikasi, integritas, kemampuan berinovasi, dan semangat kolaborasi.
# llm_answer: Dexa Medica mencari profesionalisme, dedikasi, integritas, kemampuan berinovasi, dan semangat kolaborasi dalam calon karyawan.
# rouge_l_f1: 0.7272727272727273

# %% [markdown]
# # Automatic Test

# %%
from typing_extensions import TypedDict
from typing import List
class Message(TypedDict):
    role: str
    content: str

class QnaState(TypedDict):
    messages: List[Message]

# %%
from typing import Dict, Any
def prepare_graph_input(example: Dict[str, Any]) -> QnaState:
    print(example)
    question = example.get("question", "")
    
    return QnaState(
        messages=[
            Message(role="user", content=question)
        ]
    )

def graph_wrapper(example: Dict[str, Any]) -> Dict[str, str]:
    try:
        # Convert example to graph input format
        graph_input = prepare_graph_input(example)
        
        # Invoke the graph - it returns dict with 'answer' key
        result = graph.invoke(graph_input)
        
        # Graph already returns 'answer' field, so just pass it through
        return {"answer": result.get("answer", "")}
    
    except Exception as e:
        print(f"Error processing example: {e}")
        return {"answer": ""}

# %%
from langsmith import evaluate, Client
from rouge_score import rouge_scorer
from agents.DOCSQNA import graph

client = Client()
dataset_name = "ds-crushing-mountain-99"

def exact_match(outputs: dict, reference_outputs: dict) -> bool:
    return outputs.get("answer", "") == reference_outputs.get("answer", "")

def rouge_l_f1_evaluator(outputs: dict, reference_outputs: dict) -> float:
    """
    Compute ROUGE-L F1 score between model output and reference answer.
    Assumes outputs and reference_outputs are dicts with 'answer' keys.
    """
    scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)
    output_text = outputs.get("answer", "")
    reference_text = reference_outputs.get("answer", "")
    scores = scorer.score(reference_text, output_text)
    return scores['rougeL'].fmeasure

evaluate(
    graph_wrapper,
    data=dataset_name,
    evaluators=[exact_match, rouge_l_f1_evaluator],
    experiment_prefix="ds-crushing-mountain-99 experiment"
)
# Out:
# View the evaluation results for experiment: 'ds-crushing-mountain-99 experiment-cbc4ed0e' at:
# https://smith.langchain.com/o/a9b0e3b6-35e5-411a-86ec-d368c8730760/datasets/0d84d8fd-bee0-4947-95d7-e65dbdbe4fb7/compare?selectedSessions=2a770dce-cc9d-4bac-8156-f41b2378ee86
# 0it [00:00, ?it/s]
# {'question': 'Apakah Dexa Medica terdaftar di Bursa Efek Indonesia?'}
# 0it [00:08, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 22
#      19     scores = scorer.score(reference_text, output_text)
#      20     return scores['rougeL'].fmeasure
# ---> 22 evaluate(
#      23     graph_wrapper,
#      24     data=dataset_name,
#      25     evaluators=[exact_match, rouge_l_f1_evaluator],
#      26     experiment_prefix="ds-crushing-mountain-99 experiment"
#      27 )
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\langsmith\evaluation\_runner.py:418, in evaluate(target, data, evaluators, summary_evaluators, metadata, experiment_prefix, description, max_concurrency, num_repetitions, client, blocking, experiment, upload_results, **kwargs)
#     416     _warn_once("'upload_results' parameter is in beta.")
#     417 logger.debug(f"Running evaluation over target system {target}...")
# --> 418 return _evaluate(
#     419     target,
#     420     data=data,
#     421     evaluators=cast(Optional[Sequence[EVALUATOR_T]], evaluators),
#     422     summary_evaluators=summary_evaluators,
#     423     metadata=metadata,
#     424     experiment_prefix=experiment_prefix,
#     425     description=description,
#     426     max_concurrency=max_concurrency,
#     427     num_repetitions=num_repetitions,
#     428     client=client,
#     429     blocking=blocking,
#     430     experiment=experiment,
#     431     upload_results=upload_results,
#     432 )
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\langsmith\evaluation\_runner.py:1080, in _evaluate(target, data, evaluators, summary_evaluators, metadata, experiment_prefix, description, max_concurrency, num_repetitions, client, blocking, experiment, upload_results)
#    1078     manager = manager.with_summary_evaluators(summary_evaluators)
#    1079 # Start consuming the results.
# -> 1080 results = ExperimentResults(manager, blocking=blocking)
#    1081 return results
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\langsmith\evaluation\_runner.py:557, in ExperimentResults.__init__(self, experiment_manager, blocking)
#     555 else:
#     556     self._thread = None
# --> 557     self._process_data()
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\langsmith\evaluation\_runner.py:582, in ExperimentResults._process_data(self)
#     580 tqdm = _load_tqdm()
#     581 results = self._manager.get_results()
# --> 582 for item in tqdm(results):
#     583     self._queue.put(item)
#     584     self._results.append(item)
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\tqdm\std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\langsmith\evaluation\_runner.py:1531, in _ExperimentManager.get_results(self)
#    1529 def get_results(self) -> Iterable[ExperimentResultRow]:
#    1530     """Return the traces, evaluation results, and associated examples."""
# -> 1531     for run, example, evaluation_results in zip(
#    1532         self.runs, self.examples, self.evaluation_results
#    1533     ):
#    1534         yield ExperimentResultRow(
#    1535             run=run,
#    1536             example=example,
#    1537             evaluation_results=evaluation_results,
#    1538         )
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\langsmith\evaluation\_runner.py:1500, in <genexpr>(.0)
#    1492 # Split the generator into three so the manager
#    1493 # can consume each value individually.
#    1494 r1, r2, r3 = itertools.tee(experiment_results, 3)
#    1495 return _ExperimentManager(
#    1496     (result["example"] for result in r1),
#    1497     experiment=self._experiment,
#    1498     metadata=self._metadata,
#    1499     client=self.client,
# -> 1500     runs=(result["run"] for result in r2),
#    1501     evaluation_results=(result["evaluation_results"] for result in r3),
#    1502     summary_results=self._summary_results,
#    1503     include_attachments=self._include_attachments,
#    1504     upload_results=self._upload_results,
#    1505 )
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\langsmith\evaluation\_runner.py:1698, in _ExperimentManager._score(self, evaluators, max_concurrency)
#    1696 if max_concurrency == 0:
#    1697     context = copy_context()
# -> 1698     for current_results in self.get_results():
#    1699         yield context.run(
#    1700             self._run_evaluators,
#    1701             evaluators,
#    1702             current_results,
#    1703             executor,
#    1704         )
#    1705 else:
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\langsmith\evaluation\_runner.py:1531, in _ExperimentManager.get_results(self)
#    1529 def get_results(self) -> Iterable[ExperimentResultRow]:
#    1530     """Return the traces, evaluation results, and associated examples."""
# -> 1531     for run, example, evaluation_results in zip(
#    1532         self.runs, self.examples, self.evaluation_results
#    1533     ):
#    1534         yield ExperimentResultRow(
#    1535             run=run,
#    1536             example=example,
#    1537             evaluation_results=evaluation_results,
#    1538         )
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\langsmith\evaluation\_runner.py:1469, in <genexpr>(.0)
#    1457 _experiment_results = context.run(
#    1458     self._predict,
#    1459     target,
#    1460     max_concurrency=max_concurrency,
#    1461     include_attachments=_target_include_attachments(target),
#    1462 )
#    1463 r1, r2 = itertools.tee(_experiment_results, 2)
#    1464 return _ExperimentManager(
#    1465     (pred["example"] for pred in r1),
#    1466     experiment=self._experiment,
#    1467     metadata=self._metadata,
#    1468     client=self.client,
# -> 1469     runs=(pred["run"] for pred in r2),
#    1470     upload_results=self._upload_results,
#    1471     # TODO: Can't do multiple prediction rounds rn.
#    1472     include_attachments=self._include_attachments,
#    1473 )
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\langsmith\evaluation\_runner.py:1567, in _ExperimentManager._predict(self, target, max_concurrency, include_attachments)
#    1565 if max_concurrency == 0:
#    1566     for example in self.examples:
# -> 1567         yield _forward(
#    1568             fn,
#    1569             example,
#    1570             self.experiment_name,
#    1571             self._metadata,
#    1572             self.client,
#    1573             self._upload_results,
#    1574             include_attachments,
#    1575         )
#    1577 else:
#    1578     with ls_utils.ContextThreadPoolExecutor(max_concurrency) as executor:
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\langsmith\evaluation\_runner.py:1905, in _forward(fn, example, experiment_name, metadata, client, upload_results, include_attachments)
#    1903 arg_names = _get_target_args(fn)
#    1904 args = [getattr(example, argn) for argn in arg_names]
# -> 1905 fn(*args, langsmith_extra=langsmith_extra)
#    1906 # Reset attachment readers if attachments were used.
#    1907 if include_attachments and example.attachments is not None:
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\langsmith\run_helpers.py:633, in traceable.<locals>.decorator.<locals>.wrapper(langsmith_extra, *args, **kwargs)
#     631     if func_accepts_parent_run:
#     632         kwargs["run_tree"] = run_container["new_run"]
# --> 633     function_result = run_container["context"].run(func, *args, **kwargs)
#     634 except BaseException as e:
#     635     _cleanup_traceback(e)
#
# Cell In[4], line 18, in graph_wrapper(example)
#      15 graph_input = prepare_graph_input(example)
#      17 # Invoke the graph - it returns dict with 'answer' key
# ---> 18 result = graph.invoke(graph_input)
#      20 # Graph already returns 'answer' field, so just pass it through
#      21 return {"answer": result.get("answer", "")}
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\langgraph\pregel\__init__.py:2823, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, **kwargs)
#    2820 chunks: list[Union[dict[str, Any], Any]] = []
#    2821 interrupts: list[Interrupt] = []
# -> 2823 for chunk in self.stream(
#    2824     input,
#    2825     config,
#    2826     stream_mode=stream_mode,
#    2827     output_keys=output_keys,
#    2828     interrupt_before=interrupt_before,
#    2829     interrupt_after=interrupt_after,
#    2830     checkpoint_during=checkpoint_during,
#    2831     debug=debug,
#    2832     **kwargs,
#    2833 ):
#    2834     if stream_mode == "values":
#    2835         if (
#    2836             isinstance(chunk, dict)
#    2837             and (ints := chunk.get(INTERRUPT)) is not None
#    2838         ):
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\langgraph\pregel\__init__.py:2461, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2455     # Similarly to Bulk Synchronous Parallel / Pregel model
#    2456     # computation proceeds in steps, while there are channel updates.
#    2457     # Channel updates from step N are only visible in step N+1
#    2458     # channels are guaranteed to be immutable for the duration of the step,
#    2459     # with channel updates applied only at the transition between steps.
#    2460     while loop.tick(input_keys=self.input_channels):
# -> 2461         for _ in runner.tick(
#    2462             loop.tasks.values(),
#    2463             timeout=self.step_timeout,
#    2464             retry_policy=self.retry_policy,
#    2465             get_waiter=get_waiter,
#    2466         ):
#    2467             # emit output
#    2468             yield from output()
#    2469 # emit output
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\langgraph\pregel\runner.py:153, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     151 t = tasks[0]
#     152 try:
# --> 153     run_with_retry(
#     154         t,
#     155         retry_policy,
#     156         configurable={
#     157             CONFIG_KEY_CALL: partial(
#     158                 _call,
#     159                 weakref.ref(t),
#     160                 retry=retry_policy,
#     161                 futures=weakref.ref(futures),
#     162                 schedule_task=self.schedule_task,
#     163                 submit=self.submit,
#     164                 reraise=reraise,
#     165             ),
#     166         },
#     167     )
#     168     self.commit(t, None)
#     169 except Exception as exc:
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\langgraph\pregel\retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\langgraph\utils\runnable.py:623, in RunnableSeq.invoke(self, input, config, **kwargs)
#     621     # run in context
#     622     with set_config_context(config, run) as context:
# --> 623         input = context.run(step.invoke, input, config, **kwargs)
#     624 else:
#     625     input = step.invoke(input, config)
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\langgraph\utils\runnable.py:377, in RunnableCallable.invoke(self, input, config, **kwargs)
#     375         run_manager.on_chain_end(ret)
#     376 else:
# --> 377     ret = self.func(*args, **kwargs)
#     378 if self.recurse and isinstance(ret, Runnable):
#     379     return ret.invoke(input, config)
#
# File d:\allen.ardy-iu\Documents\revou-gen-ai-tutorial\agents\DOCSQNA.py:44, in improve_query(state)
#      32 llm = ChatOpenAI(model=GPT_MODEL, api_key=OPENAI_API_KEY)
#      33 prompt = f"""
#      34 You are an expert assistant for Dexa Medica. The following is a chat history between a user and the assistant. The user's latest query did not return good results from the knowledge base. Please rewrite or expand the user's query to make it clearer and more likely to retrieve relevant information. Use the chat history for context if needed.
#      35
#    (...)     42 Improved query:
#      43 """
# ---> 44 improved_query = llm.invoke(prompt).content.strip()
#      45 # Increment improve_count, or set to 1 if not present
#      46 improve_count = state.get('improve_count', 0) + 1
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\langchain_core\language_models\chat_models.py:371, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     359 @override
#     360 def invoke(
#     361     self,
#    (...)    366     **kwargs: Any,
#     367 ) -> BaseMessage:
#     368     config = ensure_config(config)
#     369     return cast(
#     370         "ChatGeneration",
# --> 371         self.generate_prompt(
#     372             [self._convert_input(input)],
#     373             stop=stop,
#     374             callbacks=config.get("callbacks"),
#     375             tags=config.get("tags"),
#     376             metadata=config.get("metadata"),
#     377             run_name=config.get("run_name"),
#     378             run_id=config.pop("run_id", None),
#     379             **kwargs,
#     380         ).generations[0][0],
#     381     ).message
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\langchain_core\language_models\chat_models.py:956, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     947 @override
#     948 def generate_prompt(
#     949     self,
#    (...)    953     **kwargs: Any,
#     954 ) -> LLMResult:
#     955     prompt_messages = [p.to_messages() for p in prompts]
# --> 956     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\langchain_core\language_models\chat_models.py:775, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     772 for i, m in enumerate(input_messages):
#     773     try:
#     774         results.append(
# --> 775             self._generate_with_cache(
#     776                 m,
#     777                 stop=stop,
#     778                 run_manager=run_managers[i] if run_managers else None,
#     779                 **kwargs,
#     780             )
#     781         )
#     782     except BaseException as e:
#     783         if run_managers:
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\langchain_core\language_models\chat_models.py:1021, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1019     result = generate_from_stream(iter(chunks))
#    1020 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1021     result = self._generate(
#    1022         messages, stop=stop, run_manager=run_manager, **kwargs
#    1023     )
#    1024 else:
#    1025     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\langchain_openai\chat_models\base.py:959, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     957     generation_info = {"headers": dict(raw_response.headers)}
#     958 else:
# --> 959     response = self.client.create(**payload)
#     960 return self._create_chat_result(response, generation_info)
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\openai\resources\chat\completions\completions.py:925, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     882 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     883 def create(
#     884     self,
#    (...)    922     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     923 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     924     validate_response_format(response_format)
# --> 925     return self._post(
#     926         "/chat/completions",
#     927         body=maybe_transform(
#     928             {
#     929                 "messages": messages,
#     930                 "model": model,
#     931                 "audio": audio,
#     932                 "frequency_penalty": frequency_penalty,
#     933                 "function_call": function_call,
#     934                 "functions": functions,
#     935                 "logit_bias": logit_bias,
#     936                 "logprobs": logprobs,
#     937                 "max_completion_tokens": max_completion_tokens,
#     938                 "max_tokens": max_tokens,
#     939                 "metadata": metadata,
#     940                 "modalities": modalities,
#     941                 "n": n,
#     942                 "parallel_tool_calls": parallel_tool_calls,
#     943                 "prediction": prediction,
#     944                 "presence_penalty": presence_penalty,
#     945                 "reasoning_effort": reasoning_effort,
#     946                 "response_format": response_format,
#     947                 "seed": seed,
#     948                 "service_tier": service_tier,
#     949                 "stop": stop,
#     950                 "store": store,
#     951                 "stream": stream,
#     952                 "stream_options": stream_options,
#     953                 "temperature": temperature,
#     954                 "tool_choice": tool_choice,
#     955                 "tools": tools,
#     956                 "top_logprobs": top_logprobs,
#     957                 "top_p": top_p,
#     958                 "user": user,
#     959                 "web_search_options": web_search_options,
#     960             },
#     961             completion_create_params.CompletionCreateParamsStreaming
#     962             if stream
#     963             else completion_create_params.CompletionCreateParamsNonStreaming,
#     964         ),
#     965         options=make_request_options(
#     966             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     967         ),
#     968         cast_to=ChatCompletion,
#     969         stream=stream or False,
#     970         stream_cls=Stream[ChatCompletionChunk],
#     971     )
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\openai\_base_client.py:1239, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1225 def post(
#    1226     self,
#    1227     path: str,
#    (...)   1234     stream_cls: type[_StreamT] | None = None,
#    1235 ) -> ResponseT | _StreamT:
#    1236     opts = FinalRequestOptions.construct(
#    1237         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1238     )
# -> 1239     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\openai\_base_client.py:969, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     967 response = None
#     968 try:
# --> 969     response = self._client.send(
#     970         request,
#     971         stream=stream or self._should_stream_response_body(request=request),
#     972         **kwargs,
#     973     )
#     974 except httpx.TimeoutException as err:
#     975     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#      99 except BaseException as exc:
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\httpcore\_sync\connection.py:78, in HTTPConnection.handle_request(self, request)
#      76 with self._request_lock:
#      77     if self._connection is None:
# ---> 78         stream = self._connect(request)
#      80         ssl_object = stream.get_extra_info("ssl_object")
#      81         http2_negotiated = (
#      82             ssl_object is not None
#      83             and ssl_object.selected_alpn_protocol() == "h2"
#      84         )
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\httpcore\_sync\connection.py:156, in HTTPConnection._connect(self, request)
#     149     kwargs = {
#     150         "ssl_context": ssl_context,
#     151         "server_hostname": sni_hostname
#     152         or self._origin.host.decode("ascii"),
#     153         "timeout": timeout,
#     154     }
#     155     with Trace("start_tls", logger, request, kwargs) as trace:
# --> 156         stream = stream.start_tls(**kwargs)
#     157         trace.return_value = stream
#     158 return stream
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\site-packages\httpcore\_backends\sync.py:165, in SyncStream.start_tls(self, ssl_context, server_hostname, timeout)
#     163     else:
#     164         self._sock.settimeout(timeout)
# --> 165         sock = ssl_context.wrap_socket(
#     166             self._sock, server_hostname=server_hostname
#     167         )
#     168 except Exception as exc:  # pragma: nocover
#     169     self.close()
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\ssl.py:1104, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1101             if timeout == 0.0:
#    1102                 # non-blocking
#    1103                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1104             self.do_handshake()
#    1105 except:
#    1106     try:
#
# File c:\Users\allen.ardy-iu\AppData\Local\miniconda3\envs\revou\Lib\ssl.py:1382, in SSLSocket.do_handshake(self, block)
#    1380     if timeout == 0.0 and block:
#    1381         self.settimeout(None)
# -> 1382     self._sslobj.do_handshake()
#    1383 finally:
#    1384     self.settimeout(timeout)
#
# KeyboardInterrupt:
